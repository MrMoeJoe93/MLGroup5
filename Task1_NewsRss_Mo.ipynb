# %%
# Import required packages
import feedparser
import pandas


#############################  RSS FEED Parser  ##############################

# Define RSS feed URLs
RSS_URLS = [
    'http://www.dn.se/nyheter/m/rss/',
    'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/',
    'https://feeds.expressen.se/nyheter/',
    'http://www.svd.se/?service=rss',
    'http://api.sr.se/api/rss/program/83?format=145',
    'http://www.svt.se/nyheter/rss.xml'
]

# Initialize an empty list to store the parsed articles
posts = []

# Loop through each RSS feed URL
for url in RSS_URLS:
    try:
        # Parse the RSS feed
        feed = feedparser.parse(url)

        # Check if the feed is parsed successfully
        if feed.bozo:  # bozo flag indicates an issue in parsing
            print(f"Error parsing URL: {url}")
            continue

        # Loop through each entry in the feed
        for entry in feed.entries:
            # Extract relevant fields from the entry
            article = {
                'title': entry.get('title', 'No title'),
                'link': entry.get('link', 'No link'),
                'published': entry.get('published', 'No date'),
                'summary': entry.get('summary', 'No summary'),
                'source': url  # Add source URL for reference
            }

            # Append the structured article to the posts list
            posts.append(article)

    except Exception as e:
        print(f"An error occurred while processing the URL {url}: {e}")

# Display the number of articles retrieved
print(f"Successfully retrieved {len(posts)} articles.")

# Print the list of posts as a Pandas DataFrame
df = pandas.DataFrame(posts)
print(df)
# Out:
# Successfully retrieved 239 articles.
#                                                  title  \
# 0    ”Kinesiska fartyg tror att de äger hamnarna i ...
# 1       Fartygets spår avslöjar Kinas enorma maskineri
# 2                   Så tömmer Kina världshaven på fisk
# 3                 Skidorna stannar i Viaplay till 2030
# 4         Därför röstar ägarna om Northvolts öde i dag
# ..                                                 ...
# 234  Matbutik öppnar i Svenska kyrkans lokaler i Så...
# 235  Annas man Henrik åkte till Schweiz för dödshjä...
# 236  Här är storslagna Stockholmsbyggen – som aldri...
# 237  Sjöfartsverket: Stor brist på lotsar i hela la...
# 238  De brinner för att motverka mobbning – skapade...
#
#                                                   link  \
# 0    https://www.dn.se/varlden/kinesiska-fartyg-tro...
# 1    https://www.dn.se/varlden/fartygets-spar-avslo...
# 2    https://www.dn.se/varlden/sa-tommer-kina-varld...
# 3    https://www.dn.se/sport/skidorna-stannar-i-via...
# 4    https://www.dn.se/ekonomi/darfor-rostar-agarna...
# ..                                                 ...
# 234  https://www.svt.se/nyheter/lokalt/dalarna/matb...
# 235  https://www.svt.se/nyheter/lokalt/skane/annas-...
# 236  https://www.svt.se/kultur/har-ar-de-storslagna...
# 237  https://www.svt.se/nyheter/lokalt/sormland/sjo...
# 238  https://www.svt.se/nyheter/lokalt/vasternorrla...
#
#                            published  \
# 0     Wed, 8 Jan 2025 11:04:22 +0100
# 1     Wed, 8 Jan 2025 11:01:18 +0100
# 2     Wed, 8 Jan 2025 11:01:03 +0100
# 3     Wed, 8 Jan 2025 10:54:57 +0100
# 4     Wed, 8 Jan 2025 10:52:06 +0100
# ..                               ...
# 234  Wed, 08 Jan 2025 05:30:06 +0100
# 235  Wed, 08 Jan 2025 05:30:06 +0100
# 236  Wed, 08 Jan 2025 05:30:06 +0100
# 237  Wed, 08 Jan 2025 05:30:06 +0100
# 238  Wed, 08 Jan 2025 05:30:06 +0100
#
#                                                summary  \
# 0    När Elsa Vega var 24 år köpte hon sin första e...
# 1    I fyra år har den kinesiska fiskebåten Rong Ye...
# 2    Fenor skärs av hajar, delfiner dödas för att a...
# 3    Världscupen i såväl längdskidor som alpint kom...
# 4    Om några timmar samlas batteritillverkaren Nor...
# ..                                                 ...
# 234  Det har saknats en matbutik i Sågmyra under må...
# 235  Efter sex år med sjukdomen ALS valde Annas man...
# 236  En jättearena i Årsta och rekordhöga skyskrapo...
# 237  Det blåser kuling på Östersjön när lotsen Hann...
# 238  Kan man lära barn att vara snälla mot varandra...
#
#                                 source
# 0      http://www.dn.se/nyheter/m/rss/
# 1      http://www.dn.se/nyheter/m/rss/
# 2      http://www.dn.se/nyheter/m/rss/
# 3      http://www.dn.se/nyheter/m/rss/
# 4      http://www.dn.se/nyheter/m/rss/
# ..                                 ...
# 234  http://www.svt.se/nyheter/rss.xml
# 235  http://www.svt.se/nyheter/rss.xml
# 236  http://www.svt.se/nyheter/rss.xml
# 237  http://www.svt.se/nyheter/rss.xml
# 238  http://www.svt.se/nyheter/rss.xml
#
# [239 rows x 5 columns]
